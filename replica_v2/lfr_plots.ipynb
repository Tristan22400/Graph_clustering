# %%
import matplotlib.pyplot as plt

# X-axis: index of experiment / configuration
x = [0.01, 0.05, 0.1, 0.2, 0.3, 0.4]

# ----- NMI data -----
nmi_kmeans = [0.5304, 0.3540, 0.2113, 0.0783, 0.0189, 0.0132]
nmi_sc     = [0.9736, 0.8908, 0.8312, 0.2159, 0.0088, 0.0098]
nmi_gb     = [0.8142, 0.7578, 0.5882, 0.1441, 0.0332, 0.0206]
nmi_ge     = [0.8142, 0.7578, 0.5882, 0.1162, 0.0072, 0.0171]

# ----- Ncut data -----
ncut_kmeans = [1.0862, 1.0761, 1.1151, 1.2737, 1.1377, 1.2212]
ncut_sc     = [0.0081, 0.0822, 0.2826, 0.5453, 0.5859, 0.5516]
ncut_ge     = [0.1769, 0.2549, 0.4431, 0.8892, 1.1811, 0.9800]

# ----- Create a figure with 2 subplots side by side -----
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# ==== Left subplot: Ncut ====
ax = axes[0]
ax.plot(x, ncut_kmeans, marker='o', label='avg-ncut-km')
ax.plot(x, ncut_sc,     marker='s', label='avg-ncut-sc')
ax.plot(x, ncut_ge,     marker='d', label='best-avg-ncut-ge')
ax.set_xlabel('LFR mixing parameter (mu)')
ax.set_ylabel('Ncut')
ax.set_title('Ncut vs mu')
ax.grid(True)
ax.legend()

# ==== Right subplot: NMI ====
ax = axes[1]
ax.plot(x, nmi_kmeans, marker='o', label='avg-nmi-km')
ax.plot(x, nmi_sc,     marker='s', label='avg-nmi-sc')
ax.plot(x, nmi_ge,     marker='d', label='best-avg-nmi-ge')
ax.plot(x, nmi_gb,     marker='^', label='best-avg-nmi-geB')
ax.set_xlabel('LFR mixing parameter (mu)')
ax.set_ylabel('NMI')
ax.set_title('NMI vs mu')
ax.grid(True)
ax.legend()


plt.tight_layout()
plt.savefig('lfr_results.png', dpi=300)

# %%
import matplotlib.pyplot as plt

# X-axis: index of experiment / configuration
x = [0.01, 0.05, 0.1, 0.2, 0.3, 0.4]

# ----- NMI data -----
nmi_kmeans = [0.5304, 0.3540, 0.2113, 0.0783, 0.0189, 0.0132]
nmi_sc     = [0.9736, 0.8908, 0.8312, 0.2159, 0.0088, 0.0098]
nmi_gb     = [0.8142, 0.7578, 0.5882, 0.1441, 0.0332, 0.0206]
nmi_ge     = [0.8142, 0.7578, 0.5882, 0.1162, 0.0072, 0.0171]

# ----- Ncut data -----
ncut_kmeans = [1.0862, 1.0761, 1.1151, 1.2737, 1.1377, 1.2212]
ncut_sc     = [0.0081, 0.0822, 0.2826, 0.5453, 0.5859, 0.5516]
ncut_ge     = [0.1769, 0.2549, 0.4431, 0.8892, 1.1811, 0.9800]

# ========== NMI plot ==========
plt.figure()
plt.plot(x, nmi_kmeans, marker='o', label='avg-nmi-os')
plt.plot(x, nmi_sc,     marker='s', label='avg-nmi-sc')
plt.plot(x, nmi_ge,     marker='d', label='best-avg-nmi-geU')
plt.plot(x, nmi_gb,     marker='^', label='best-avg-nmi-geB')
plt.xlabel('Index')
plt.ylabel('NMI')
plt.title('NMI vs Index')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# ========== Ncut plot ==========
plt.figure()
plt.plot(x, ncut_kmeans, marker='o', label='avg-ncut-os')
plt.plot(x, ncut_sc,     marker='s', label='avg-ncut-sc')
plt.plot(x, ncut_ge,     marker='d', label='best-avg-ncut-ge')
plt.xlabel('Index')
plt.ylabel('Ncut')
plt.title('Ncut vs Index')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
